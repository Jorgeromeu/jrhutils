# %%
# %load_ext autoreload
# %autoreload 2

from jrhutils.mpl_utils import add_zoom_inset, bbox_around_point
from jrhutils.test_utils import test_img
import matplotlib.pyplot as plt
import numpy as np

img = test_img("a")

fig, axs = plt.subplots()
axs.imshow(img, extent=[0,1,1,0])

data = np.random.uniform(size=(100,2))
axs.scatter(data[:,0], data[:,1], s=1, c="red")

bbox = bbox_around_point([0.5, 0.5], 0.1)
add_zoom_inset(axs, bbox)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
